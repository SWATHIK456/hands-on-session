# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import plotly

# %%
df = pd.read_excel(r"C:\Users\hpint\superstore_sales.xlsx")

# %%
df
# Out:
#       Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0            3 2010-10-13            Low               6    261.5400
# 1          293 2012-10-01           High              49  10123.0200
# 2          293 2012-10-01           High              27    244.5700
# 3          483 2011-07-10           High              30   4965.7595
# 4          515 2010-08-28  Not Specified              19    394.2700
# ...        ...        ...            ...             ...         ...
# 8394     55558 2010-08-09         Medium               8   1294.0400
# 8395     55558 2010-08-09         Medium              23    392.5700
# 8396     56550 2011-04-08  Not Specified              37    823.7800
# 8397     56550 2011-04-08  Not Specified               8    469.8375
# 8398     56581 2009-02-08           High              20   2026.0100
#
#       Discount       Ship Mode   Profit  Unit Price  Shipping Cost  \
# 0         0.04     Regular Air  -213.25       38.94          35.00
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Priority', 'Order Quantity', 'Sales',
#        'Discount', 'Ship Mode', 'Profit', 'Unit Price', 'Shipping Cost',
#        'Customer Name', 'Province', 'Region', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
df['Sales'].iloc[0:5]
# Out:
# 0      261.5400
# 1    10123.0200
# 2      244.5700
# 3     4965.7595
# 4      394.2700
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(20,5))
plt.plot(df['Sales'].iloc[0:10],marker='4',markerfacecolor='white', markersize=10,markeredgecolor='b',markeredgewidth=2)
plt.xlabel("index")
plt.ylabel("sales")
plt.title("sales vs index")
#plt.xlim(0,7)
#plt.ylim(0,100)
# Out:
# Text(0.5, 1.0, 'sales vs index')

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Sales'].iloc[0:10])
plt.plot(df['Sales'].iloc[10:20])
plt.xlabel("index")
plt.ylabel("sales")
plt.title("sales vs indes")
# Out:
# Text(0.5, 1.0, 'sales vs indes')

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Sales'].iloc[0:10].values)
plt.plot(df['Sales'].iloc[10:20].values)
plt.xlabel("index")
plt.ylabel("sales")
plt.title("sales vs indes")
# Out:
# Text(0.5, 1.0, 'sales vs indes')

# %%
plt.subplot(2,2,1)
plt.plot(df['Sales'].iloc[0:10].values)
plt.xlabel("index")
plt.ylabel("sales")
plt.title("sales vs indes")
plt.subplot(2,2,2)
plt.plot(df['Sales'].iloc[10:20].values)
plt.xlabel("index")
plt.ylabel("sales")
plt.title("sales vs indes")
plt.subplot(2,2,3)
plt.plot(df['Sales'].iloc[20:30].values)
plt.xlabel("index")
plt.ylabel("sales")
plt.subplot(2,2,4)
plt.plot(df['Sales'].iloc[30:40].values)
plt.xlabel("index")
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
plt.plot(df['Sales'].iloc[0:10].values)
plt.plot(df['Sales'].iloc[10:20].values)
plt.plot(df['Sales'].iloc[20:30].values)
plt.plot(df['Sales'].iloc[30:40].values)
plt.xlabel("index")
plt.ylabel("sales")
plt.title("sales vs indes")
# Out:
# Text(0.5, 1.0, 'sales vs indes')

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Priority', 'Order Quantity', 'Sales',
#        'Discount', 'Ship Mode', 'Profit', 'Unit Price', 'Shipping Cost',
#        'Customer Name', 'Province', 'Region', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
sales_by_date=df.groupby("Order Date")['Sales'].sum()
sales_by_date.head()
# Out:
# Order Date
# 2009-01-01     1052.8400
# 2009-01-02    11101.8700
# 2009-01-03    31997.8555
# 2009-01-04     1254.2500
# 2009-01-05    39734.4040
# Name: Sales, dtype: float64

# %%
sales_by_date.index
# Out:
# DatetimeIndex(['2009-01-01', '2009-01-02', '2009-01-03', '2009-01-04',
#                '2009-01-05', '2009-01-06', '2009-01-07', '2009-01-08',
#                '2009-01-09', '2009-01-10',
#                ...
#                '2012-12-21', '2012-12-22', '2012-12-23', '2012-12-24',
#                '2012-12-25', '2012-12-26', '2012-12-27', '2012-12-28',
#                '2012-12-29', '2012-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=1418, freq=None)

# %%
plt.figure(figsize=(20,5))
sales_by_date=df.groupby("Order Date")['Profit'].sum()
sales_by_date.head()
plt.plot(sales_by_date.index,sales_by_date.values)
plt.title("sale by index",fontsize=20)
plt.xlabel("order date",fontsize=14)
plt.ylabel("Profit",fontsize=14)
plt.title("daily profit trend")
plt.xticks(rotation=45)
plt.grid(True,linestyle='--')
plt.show()

# %%
plt.figure(figsize=(20,5))
sales_by_date=df.groupby("Region")['Profit'].sum()
plt.bar(sales_by_date.index,sales_by_date.values,color='g')
plt.title("Total slaes by region",fontsize=20)
plt.xlabel("Region",fontsize=14)
plt.ylabel("sales",fontsize=14)
#plt.title("daily profit trend")
#plt.xticks(rotation=45)
#plt.grid(True,linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,5))
sales_by_date=df.groupby("Region")['Profit'].sum().sort_values(ascending=False)
plt.bar(sales_by_date.index,sales_by_date.values,color='g')
plt.title("Total slaes by region",fontsize=20)
plt.xlabel("Region",fontsize=14)
plt.ylabel("sales",fontsize=14)
#plt.title("daily profit trend")
#plt.xticks(rotation=45)
#plt.grid(True,linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,5))
sales_by_date=df.groupby("Region")['Profit'].sum().sort_values(ascending=False)
plt.bar(sales_by_date.index,sales_by_date.values,color=['g','r','b','orange','violet','indigo','yellow','pink'])
plt.title("Total slaes by region",fontsize=20)
plt.xlabel("Region",fontsize=14)
plt.ylabel("sales",fontsize=14)
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize=(5,5))
sales_by_date=df.groupby("Region")['Profit'].sum().sort_values(ascending=False)
plt.barh(sales_by_date.index,sales_by_date.values,color=['g','r','b','orange','violet','indigo','yellow','pink'])
plt.title("Total slaes by region",fontsize=20)
plt.xlabel("Region",fontsize=14)
plt.ylabel("sales",fontsize=14)
plt.xticks(rotation=45)
# Out:
# (array([     0.,  50000., 100000., 150000., 200000., 250000., 300000.,
#         350000., 400000.]),
#  [Text(0.0, 0, '0'),
#   Text(50000.0, 0, '50000'),
#   Text(100000.0, 0, '100000'),
#   Text(150000.0, 0, '150000'),
#   Text(200000.0, 0, '200000'),
#   Text(250000.0, 0, '250000'),
#   Text(300000.0, 0, '300000'),
#   Text(350000.0, 0, '350000'),
#   Text(400000.0, 0, '400000')])
